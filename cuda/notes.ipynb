# %% [markdown]
# # CUDA notes
# ## In a classical execution model (SISD):
#     Sequential instructions. For instance when adding a vector, you do it sequentially with each item.
# ## In SIMT (Single instruction, multiple threads):
#     In the same example, a vector addition is done paralleling.
#     This is the model for GPUs.
#     Here we have
# The building blocks are:
# * Threads (sequential instructions)
# * Grids
#     - They are made by **Thread blocks**
#     - Thread blocks are the lower programmable entities.
#     - Is assigned to a single **shader core** (idk what that means yet)
#     - Can be 3-d
#
# We also have this, **cuda cores** are the basic unit of computation of Nvidias GPUs.
# ![image.png](attachment:image.png)
